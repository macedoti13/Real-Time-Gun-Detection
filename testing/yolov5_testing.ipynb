# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-186-g0acc5cf Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.2/166.8 GB disk)

# %% [markdown]
# # Jonh Wick video

# %% [markdown]
# ## Yolov5 Small

# %%
# !python detect.py --weights ../drive/MyDrive/yolo_weights/yolov5s.pt --img 640 --conf 0.25 --source ../drive/MyDrive/guns_videos/jonhwick.mp4
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (2248/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 (no detections), 7.8ms
# video 1/1 (2249/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 (no detections), 8.4ms
# video 1/1 (2250/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 (no detections), 7.6ms
# video 1/1 (2251/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 (no detections), 8.1ms
# video 1/1 (2252/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 (no detections), 9.7ms
# video 1/1 (2253/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 (no detections), 9.5ms
# video 1/1 (2254/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 (no detections), 18.0ms
# video 1/1 (2255/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 (no detections), 10.3ms
# video 1/1 (2256/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 (no detections), 7.9ms
# ...

# %% [markdown]
# ## Yolov5 Medium

# %%
# !python detect.py --weights ../drive/MyDrive/yolo_weights/yolov5m.pt --img 640 --conf 0.25 --source ../drive/MyDrive/guns_videos/jonhwick.mp4
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (2248/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 1 armed, 1 gun, 10.3ms
# video 1/1 (2249/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 1 armed, 1 gun, 9.9ms
# video 1/1 (2250/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 1 armed, 1 gun, 9.9ms
# video 1/1 (2251/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 1 armed, 1 gun, 9.9ms
# video 1/1 (2252/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 1 armed, 9.9ms
# video 1/1 (2253/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 1 armed, 10.0ms
# video 1/1 (2254/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 1 armed, 9.9ms
# video 1/1 (2255/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 (no detections), 9.9ms
# video 1/1 (2256/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 (no detections), 9.9ms
# ...

# %% [markdown]
# ## Yolov5 Large

# %%
# !python detect.py --weights ../drive/MyDrive/yolo_weights/yolov5l.pt --img 640 --conf 0.25 --source ../drive/MyDrive/guns_videos/jonhwick.mp4
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (2248/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 1 unarmed, 14.0ms
# video 1/1 (2249/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 1 unarmed, 15.1ms
# video 1/1 (2250/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 1 unarmed, 14.2ms
# video 1/1 (2251/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 1 unarmed, 14.4ms
# video 1/1 (2252/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 1 unarmed, 14.1ms
# video 1/1 (2253/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 1 unarmed, 14.9ms
# video 1/1 (2254/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 (no detections), 14.1ms
# video 1/1 (2255/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 (no detections), 14.5ms
# video 1/1 (2256/7245) /content/drive/MyDrive/guns_videos/jonhwick.mp4: 288x640 1 unarmed, 13.9ms
# ...
