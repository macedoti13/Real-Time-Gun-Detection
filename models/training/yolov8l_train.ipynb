# %% [markdown]
# # Yolo v8 large training

# %% [markdown]
# ## Config

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.122 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 24.1/166.8 GB disk)

# %% [markdown]
# ## Training

# %%
# !yolo train model=yolov8l.pt data=config.yaml epochs=50 imgsz=640
# Out:
# ...
# 100% 83.7M/83.7M [00:05<00:00, 16.0MB/s]
# Ultralytics YOLOv8.0.122 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...
