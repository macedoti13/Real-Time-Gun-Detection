# %% [markdown]
# # Yolo v8 small training

# %% [markdown]
# ## Config

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.122 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 24.1/166.8 GB disk)

# %% [markdown]
# ## Training

# %%
# !yolo train model=yolov8s.pt data=config.yaml epochs=50 imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:01<00:00, 19.5MB/s]
# Ultralytics YOLOv8.0.122 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...
